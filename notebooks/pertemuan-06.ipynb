# %% [markdown]
# # Pertemuan 06 — Praktikum NLP
#
# LSTM dan GRU menambahkan mekanisme gate yang mengontrol informasi mana yang disimpan, ditulis, dan dibaca. Jalur cell state pada LSTM membantu gradient bergerak lebih stabil sehingga dependensi yang lebih panjang lebih mudah dipelajari dibanding RNN sederhana.
#
# ## Tujuan
#
# - Menjalankan contoh kode secara mandiri.
# - Menghubungkan hasil program dengan teori pada microsite.
# - Menyimpan interpretasi, bukan hanya output.

# %% [markdown]
# ## Referensi
#
# - [D2L 10.1–10.4 — Modern RNNs](https://d2l.ai/chapter_recurrent-modern/index.html)
# - [DLP Ch. 10–11 — Recurrent layers](https://deeplearningwithpython.io/chapters/)

# %% [markdown]
# ## Contoh program
#
# **Perbandingan LSTM dan GRU**
# Fungsi yang sama membuat perbandingan konfigurasi lebih adil.

# %%
import keras
from keras import layers

def build_model(cell="lstm", vocab=1000):
    sequence = layers.GRU(48) if cell == "gru" else layers.LSTM(48)
    inputs = keras.Input(shape=(None,), dtype="int32")
    x = layers.Embedding(vocab, 64, mask_zero=True)(inputs)
    x = sequence(x)
    x = layers.Dropout(.3)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)
    model = keras.Model(inputs, outputs)
    model.compile("adam", "binary_crossentropy", metrics=["accuracy"])
    return model

for cell in ["lstm", "gru"]:
    model = build_model(cell)
    print(cell, "parameters:", model.count_params())

# %% [markdown]
# ## Interpretasi dan latihan
#
# 1. Jelaskan perbedaan fungsi forget gate LSTM dan update gate GRU.
# 2. Laporkan parameter, waktu per epoch, macro-F1, dan variasi tiga seed.
#
# Tuliskan hasil, penjelasan, dan keterbatasan eksperimen pada cell baru di bawah.

# %%
# Tulis eksperimen dan interpretasi Anda di sini
