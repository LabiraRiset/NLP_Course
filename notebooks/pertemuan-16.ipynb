# %% [markdown]
# # Pertemuan 16 — Praktikum NLP
#
# UAS menutup siklus pembelajaran dengan verifikasi teori individual dan penyerahan produk ilmiah kelompok. “Siap submit” berarti naskah mengikuti template venue, evidence konsisten dengan klaim, kode dapat dijalankan, dan seluruh persyaratan etika serta administrasi telah diperiksa.
#
# ## Tujuan
#
# - Menjalankan contoh kode secara mandiri.
# - Menghubungkan hasil program dengan teori pada microsite.
# - Menyimpan interpretasi, bukan hanya output.

# %% [markdown]
# ## Referensi
#
# - Lihat materi dan ketentuan asesmen pada microsite.

# %% [markdown]
# ## Contoh program
#
# **Checklist rilis artefak**
# Jalankan pemeriksaan sederhana sebelum pengumpulan.

# %%
from pathlib import Path

required = [
 "README.md", "requirements.txt", "src",
 "configs", "results", "paper"
]
missing = [name for name in required if not Path(name).exists()]
if missing:
    print("Belum lengkap:", missing)
else:
    print("Struktur minimum tersedia. Lanjutkan smoke test.")

# %% [markdown]
# ## Interpretasi dan latihan
#
# 1. Lakukan smoke test dari environment bersih.
# 2. Pastikan semua angka pada abstract, tabel, discussion, dan conclusion konsisten.
#
# Tuliskan hasil, penjelasan, dan keterbatasan eksperimen pada cell baru di bawah.

# %%
# Tulis eksperimen dan interpretasi Anda di sini
