# %% [markdown]
# # Pertemuan 15 — Praktikum NLP
#
# Artikel ilmiah bukan dokumentasi kronologis proses coding. Ia adalah argumen: masalah penting, gap tertentu belum terjawab, metode dirancang untuk menjawabnya, hasil menyediakan bukti, dan diskusi membatasi makna bukti tersebut.
#
# ## Tujuan
#
# - Menjalankan contoh kode secara mandiri.
# - Menghubungkan hasil program dengan teori pada microsite.
# - Menyimpan interpretasi, bukan hanya output.

# %% [markdown]
# ## Referensi
#
# - [D2L — References](https://d2l.ai/chapter_references/index.html)
# - [DLP — Chapters and scientific workflow](https://deeplearningwithpython.io/chapters/)

# %% [markdown]
# ## Contoh program
#
# **Membuat tabel hasil dari log**
# Pisahkan data hasil dari formatting agar tabel dapat diperbarui otomatis.

# %%
import pandas as pd

results = pd.DataFrame([
 {"model":"TF-IDF + LR", "macro_f1":.78, "params":"0.12M"},
 {"model":"BiLSTM", "macro_f1":.81, "params":"1.80M"},
 {"model":"BERT FT", "macro_f1":.87, "params":"110M"}
])
results["delta_vs_baseline"] = results.macro_f1 - results.macro_f1.iloc[0]
print(results.to_markdown(index=False, floatfmt=".3f"))
results.to_csv("table_results.csv", index=False)

# %% [markdown]
# ## Interpretasi dan latihan
#
# 1. Lakukan peer review dengan format summary, strengths, major concerns, minor concerns, dan questions.
# 2. Tulis ulang tiga klaim berlebihan menjadi klaim yang dibatasi evidence.
#
# Tuliskan hasil, penjelasan, dan keterbatasan eksperimen pada cell baru di bawah.

# %%
# Tulis eksperimen dan interpretasi Anda di sini
