# %% [markdown]
# # Pertemuan 08 — Praktikum NLP
#
# UTS mengukur dua sisi kompetensi. Ujian pilihan ganda memverifikasi penguasaan teori pertemuan 1–7 secara individual. Draft program dan tulisan ilmiah menunjukkan bahwa kelompok mampu menerapkan teori menjadi rancangan eksperimen yang dapat diperiksa.
#
# ## Tujuan
#
# - Menjalankan contoh kode secara mandiri.
# - Menghubungkan hasil program dengan teori pada microsite.
# - Menyimpan interpretasi, bukan hanya output.

# %% [markdown]
# ## Referensi
#
# - Lihat materi dan ketentuan asesmen pada microsite.

# %% [markdown]
# ## Contoh program
#
# **Checklist reproducibility sederhana**
# Simpan metadata di setiap eksperimen.

# %%
from datetime import datetime
import json, platform

run = {
    "time": datetime.now().isoformat(timespec="seconds"),
    "python": platform.python_version(),
    "seed": 42,
    "split": "stratified 70/15/15",
    "model": "tfidf-logreg",
    "params": {"ngram_range": [1, 2], "C": 1.0},
    "validation_macro_f1": None
}
print(json.dumps(run, indent=2))

# %% [markdown]
# ## Interpretasi dan latihan
#
# 1. Gunakan checklist untuk melakukan self-audit draft sebelum dikumpulkan.
# 2. Setiap anggota menyiapkan penjelasan individual mengenai satu keputusan metodologis.
#
# Tuliskan hasil, penjelasan, dan keterbatasan eksperimen pada cell baru di bawah.

# %%
# Tulis eksperimen dan interpretasi Anda di sini
